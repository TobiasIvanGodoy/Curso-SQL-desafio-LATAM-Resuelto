# %%
import sqlite3 as sql
import pandas as pd

con = sql.connect("casas.db")
con.close()

# %%
#DATE() se puede utilizar para obtener la fecha del día de hoy.

#SELECT columna FROM tabla WHERE fecha = DATE(); 

#SELECT columna FROM tabla WHERE fecha = DATE('now');

# %%
#Podemos también sumarle fechas a la fecha actual para obtener fechas futuras.

#SELECT columna FROM tabala WHERE fecha > DATE('now', '1 day');
#SELECT columna FROM tabala WHERE fecha > DATE('now', '3 week');
#SELECT columna FROM tabala WHERE fecha > DATE('now', '2 month');

# %%
#SELECT columna FROM tabala WHERE fecha > DATE('now', '-1 day'); Para restar.

# %%
#Para seleccionar especificamente el año, mes, y juntos

#SELECT monto, strftime('%Y', fecha_venta) AS año_venta FROM ventas;
#SELECT monto, strftime('%m', fecha_venta) AS mes_venta, strftime('%Y', fecha_venta) as año_venta FROM ventas;
#SELECT monto, strftime('%m-%Y', fecha_venta) AS mes_año FROM ventas;

# %%
#Por último, podemos usar también esto para filtrar la consulta con la claúsula WHERE.

#SELECT * FROM ventas WHERE strftime('%Y', fecha_venta) = '2015';
